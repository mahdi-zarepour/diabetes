# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
df = pd.read_csv('../../data/diabetes.csv')

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
knn = KNeighborsClassifier(n_neighbors=12)

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_pred = knn.predict(x_test)
y_pred = (y_pred > 0.5)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[88  8]
#  [32 26]]
# 0.7402597402597403

# %%
knn.score(x_test, y_test)
# Out:
# 0.7402597402597403

# %% [markdown]
# ### find optimal n_neighbors

# %%
train_accuracy = list()
test_accuracy = list()

# %%
neighbors_settings = range(1, 15)

# %%
for n in neighbors_settings:
    knn_n_neighbors = KNeighborsClassifier(n_neighbors=n)
    knn_n_neighbors.fit(x_train, y_train)
    train_accuracy.append(knn_n_neighbors.score(x_train, y_train))
    test_accuracy.append(knn_n_neighbors.score(x_test, y_test))

# %%
plt.plot(neighbors_settings, train_accuracy, label='train accuracy')
plt.plot(neighbors_settings, test_accuracy, label='test accuracy')
plt.ylabel('Accuracy')
plt.xlabel('N Neighbors')
plt.show()
